# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikreddy1335/CP/blob/main/ASSIGNMENT%2001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def max_meetings(meetings):
    meetings.sort(key=lambda meeting: meeting[1])
    meeting_count = 0
    last_meeting_end = -1
    for start_time, end_time in meetings:
        if start_time >= last_meeting_end:
            meeting_count += 1
            last_meeting_end = end_time
    return meeting_count
T = int(input())
for i in range(T):
    N = int(input())
    meetings = []
    for j in range(N):
        start, end = map(int, input().split())
        meetings.append((start, end))
    print(max_meetings(meetings))
# Out:
# 1
# 3
# 1 3
# 2 4
# 3 5
# 2
